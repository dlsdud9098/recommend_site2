# %%
import pickle
import pandas as pd

with open('data/all_data.data', 'rb') as f:
    a = pickle.load(f)

# for i in a:
#     print(i['page_count'])

a
# Out:
# [{'url': 'https://novel.munpia.com/453866',
#   'img': '//cdn1.munpia.com/files/attach/2025/0408/003/cV9WWn0bVRYYZY8r.jpg',
#   'title': '선독점\nFA 보상 선수가 너무 잘 던진다',
#   'author': '로웰크란',
#   'recommend': 13857,
#   'genre': '스포츠, 현대판타지',
#   'serial': '연재중',
#   'publisher': '',
#   'summary': '<지피셜: 갑자기 바꾸었다고 합니다. 둘 다 아닙니다.> <지피셜: 고심 끝에 라주엽으로 결정했다고 합니다.> 엥?',
#   'page_count': 175,
#   'page_unit': '회차',
#   'age': '전체',
#   'platform': 'munpia',
#   'keywords': '#판타지 #스포츠 #야구',
#   'viewers': 713831,
#   'type': '소설',
#   'rating': '0',
#   'id': 1},
#  {'url': 'https://novel.munpia.com/458043',
#   'img': '//cdn1.munpia.com/v2/files/cover/2025/0416/12/EuZ5TdwPUAA',
#   'title': '선독점\n경험치로 초월하는 0레벨 플레이어',
#   'author': '치트키',
#   'recommend': 56782,
#   'genre': '현대판타지, 판타지',
#   'serial': '연재중',
#   'publisher': '',
#   'summary': '레벨을 버린 순간 모든 것이 달라졌다.',
#   'page_count': 200,
#   'page_unit': '회차',
#   'age': '전체',
#   'platform': 'munpia',
#   'keywords': '#착각 #회귀 #먼치킨',
# ...

# %%
import json

with open('ai/data/process_datas.json', 'r', encoding='utf-8') as f:
    a = json.load(f)
len(a)
# Out:
# 87378
